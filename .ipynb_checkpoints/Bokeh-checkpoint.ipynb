# %% [markdown]
# # Getting Started
# ## Simple Line Example

# %%
from bokeh.plotting import figure, output_notebook, show

# %%
# prepare some data
x = [1, 2, 3, 4, 5]
y = [6, 7, 2, 4, 5]

# output to static HTML file
# output_file("lines.html", title='line plot example')
output_notebook()

# create a new plot with a title and axis labels
p = figure(title="simple line example", x_axis_label='x', y_axis_label='y')

# add a line renderer with legend and line thickness
p.line(x, y, legend='Temp.', line_width=2)

# show the results
show(p)
# Out:
#     <script type="text/javascript">
#
#       (function(global) {
#         function now() {
#           return new Date();
#         }
#
#         if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#           window._bokeh_onload_callbacks = [];
#         }
#
#         function run_callbacks() {
#           window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#           delete window._bokeh_onload_callbacks
#           console.info("Bokeh: all callbacks have finished");
#         }
#
#         function load_libs(js_urls, callback) {
#           window._bokeh_onload_callbacks.push(callback);
#           if (window._bokeh_is_loading > 0) {
#             console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#             return null;
#           }
#           if (js_urls == null || js_urls.length === 0) {
#             run_callbacks();
#             return null;
#           }
#           console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#           window._bokeh_is_loading = js_urls.length;
#           for (var i = 0; i < js_urls.length; i++) {
#             var url = js_urls[i];
#             var s = document.createElement('script');
#             s.src = url;
#             s.async = false;
#             s.onreadystatechange = s.onload = function() {
#               window._bokeh_is_loading--;
#               if (window._bokeh_is_loading === 0) {
#                 console.log("Bokeh: all BokehJS libraries loaded");
#                 run_callbacks()
#               }
#             };
#             s.onerror = function() {
#               console.warn("failed to load library " + url);
#             };
#             console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#             document.getElementsByTagName("head")[0].appendChild(s);
#           }
#         };var js_urls = ['https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.js', 'https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.js', 'https://cdn.pydata.org/bokeh/release/bokeh-compiler-0.11.0.min.js'];
#
#         var inline_js = [
#           function(Bokeh) {
#             Bokeh.set_log_level("info");
#           },
#           function(Bokeh) {
#             console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.css");
#             Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.css");
#             console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.css");
#             Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.css");
#           }
#         ];
#
#         function run_inline_js() {
#           for (var i = 0; i < inline_js.length; i++) {
#             inline_js[i](window.Bokeh);
#           }
#         }
#
#         if (window._bokeh_is_loading === 0) {
#           console.log("Bokeh: BokehJS loaded, going straight to plotting");
#           run_inline_js();
#         } else {
#           load_libs(js_urls, function() {
#             console.log("Bokeh: BokehJS plotting callback run at", now());
#             run_inline_js();
#           });
#         }
#       }(this));
#     </script>
#     <div>
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span>BokehJS successfully loaded.</span>
#     </div>
#     <div class="plotdiv" id="5c70d62d-1f85-4591-9bd5-6d2cf0846cbb"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("5c70d62d-1f85-4591-9bd5-6d2cf0846cbb");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '5c70d62d-1f85-4591-9bd5-6d2cf0846cbb' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"251ea65b-07a8-4379-abf2-03a2138b0c91": {"title": "Bokeh Application", "version": "0.11.0", "roots": {"root_ids": ["85100ea1-38ed-4ec2-9019-25c9c527940c"], "references": [{"type": "Grid", "id": "f4d8130c-ba97-466f-87e7-70ca42d2e539", "attributes": {"dimension": 1, "ticker": {"type": "BasicTicker", "id": "19029e59-4f59-45ae-99c0-edee3fd3668e"}, "plot": {"type": "Plot", "id": "85100ea1-38ed-4ec2-9019-25c9c527940c", "subtype": "Figure"}}}, {"type": "ResizeTool", "id": "fa3f3376-7833-4a56-850d-89b18d7e89cd", "attributes": {"plot": {"type": "Plot", "id": "85100ea1-38ed-4ec2-9019-25c9c527940c", "subtype": "Figure"}}}, {"type": "Legend", "id": "2619f003-0189-4ee0-8b90-5cd877e9c6d4", "attributes": {"legends": [["Temp.", [{"type": "GlyphRenderer", "id": "b0a21f51-f6cc-447d-88fe-c8cba569da54"}]]], "plot": {"type": "Plot", "id": "85100ea1-38ed-4ec2-9019-25c9c527940c", "subtype": "Figure"}}}, {"type": "Line", "id": "36e694e3-5729-4003-8c9d-2da3beb9a8f5", "attributes": {"y": {"field": "y"}, "x": {"field": "x"}, "line_color": {"value": "#1f77b4"}, "line_width": {"value": 2}}}, {"type": "BasicTickFormatter", "id": "29c41bd9-b609-4ee2-9d0a-0cf7835087dc", "attributes": {}}, {"type": "Line", "id": "ba43eb99-a311-437a-8587-3f84ad2c8ff1", "attributes": {"line_alpha": {"value": 0.1}, "x": {"field": "x"}, "line_color": {"value": "#1f77b4"}, "line_width": {"value": 2}, "y": {"field": "y"}}}, {"type": "BasicTicker", "id": "19029e59-4f59-45ae-99c0-edee3fd3668e", "attributes": {}}, {"type": "Plot", "id": "85100ea1-38ed-4ec2-9019-25c9c527940c", "attributes": {"title": "simple line example", "below": [{"type": "LinearAxis", "id": "02a16617-25a1-4a29-9fe1-4453521cdab3"}], "left": [{"type": "LinearAxis", "id": "40857a7b-35cc-4787-abdf-4630d1aaed58"}], "tool_events": {"type": "ToolEvents", "id": "b093ae15-6b3f-49b3-8326-1abebcfb2648"}, "renderers": [{"type": "LinearAxis", "id": "02a16617-25a1-4a29-9fe1-4453521cdab3"}, {"type": "Grid", "id": "3e2f7c9e-3d9a-4f87-a2df-9488ae49d478"}, {"type": "LinearAxis", "id": "40857a7b-35cc-4787-abdf-4630d1aaed58"}, {"type": "Grid", "id": "f4d8130c-ba97-466f-87e7-70ca42d2e539"}, {"type": "BoxAnnotation", "id": "437d9447-bc6f-48e2-ad98-1746d797e23a"}, {"type": "Legend", "id": "2619f003-0189-4ee0-8b90-5cd877e9c6d4"}, {"type": "GlyphRenderer", "id": "b0a21f51-f6cc-447d-88fe-c8cba569da54"}], "tools": [{"type": "PanTool", "id": "d01e9ff9-5975-4a80-bd2b-0570a19a1690"}, {"type": "WheelZoomTool", "id": "52f3a7d3-8186-4b54-ae1b-1c02ec35b33b"}, {"type": "BoxZoomTool", "id": "903ba826-4f1e-4102-9c40-9492856b49c4"}, {"type": "PreviewSaveTool", "id": "ef39d3c1-7b28-4e75-8191-4e7883c90134"}, {"type": "ResizeTool", "id": "fa3f3376-7833-4a56-850d-89b18d7e89cd"}, {"type": "ResetTool", "id": "9624bf73-9e38-4725-b64c-d2eab74289dc"}, {"type": "HelpTool", "id": "59494f42-cde7-4632-8fa8-05ea2b1835ae"}], "y_range": {"type": "DataRange1d", "id": "be850056-efb7-4fff-af40-4da4ffd5b781"}, "x_range": {"type": "DataRange1d", "id": "08442508-c30d-41ae-ab45-720f0eba4a51"}}, "subtype": "Figure"}, {"type": "ToolEvents", "id": "b093ae15-6b3f-49b3-8326-1abebcfb2648", "attributes": {}}, {"type": "ColumnDataSource", "id": "423bcd51-8258-41d2-9588-e573622b7ca7", "attributes": {"column_names": ["y", "x"], "callback": null, "data": {"y": [6, 7, 2, 4, 5], "x": [1, 2, 3, 4, 5]}}}, {"type": "LinearAxis", "id": "40857a7b-35cc-4787-abdf-4630d1aaed58", "attributes": {"formatter": {"type": "BasicTickFormatter", "id": "30b64d97-6e53-4652-9fcd-211cf0da82b8"}, "ticker": {"type": "BasicTicker", "id": "19029e59-4f59-45ae-99c0-edee3fd3668e"}, "axis_label": "y", "plot": {"type": "Plot", "id": "85100ea1-38ed-4ec2-9019-25c9c527940c", "subtype": "Figure"}}}, {"type": "DataRange1d", "id": "be850056-efb7-4fff-af40-4da4ffd5b781", "attributes": {"callback": null}}, {"type": "BasicTicker", "id": "9090093a-773e-4f65-bb45-cf6955a1fc4d", "attributes": {}}, {"type": "BoxZoomTool", "id": "903ba826-4f1e-4102-9c40-9492856b49c4", "attributes": {"overlay": {"type": ...

# %% [markdown]
# ## Multiple Series

# %%
# prepare some data
x = [0.1, 0.5, 1.0, 1.5, 2.0, 2.5, 3.0]
y0 = [i**2 for i in x]
y1 = [10**i for i in x]
y2 = [10**(i**2) for i in x]

# output to static HTML file
output_notebook()

# create a new plot
p = figure(
    tools="pan,box_zoom,reset,save",
    y_axis_type="log",
    y_range=[0.001, 10**11],
    title="log axis example",
    x_axis_label="sections",
    y_axis_label="particles"
)

# add some renderers
p.line(x, x, legend="y=x")
p.circle(x, x, legend="y=x", fill_color="white", size=8)
p.line(x, y0, legend="y=x^2", line_width=3)
p.line(x, y1, legend="y=10^x", line_color="red")
p.circle(x, y1, legend="y=10^x", fill_color="red", line_color="red", size=6)
p.line(x, y2, legend="y=10^x^2", line_color="orange", line_dash="4 4")

# show the results
show(p)
# Out:
#     <script type="text/javascript">
#
#       (function(global) {
#         function now() {
#           return new Date();
#         }
#
#         if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#           window._bokeh_onload_callbacks = [];
#         }
#
#         function run_callbacks() {
#           window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#           delete window._bokeh_onload_callbacks
#           console.info("Bokeh: all callbacks have finished");
#         }
#
#         function load_libs(js_urls, callback) {
#           window._bokeh_onload_callbacks.push(callback);
#           if (window._bokeh_is_loading > 0) {
#             console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#             return null;
#           }
#           if (js_urls == null || js_urls.length === 0) {
#             run_callbacks();
#             return null;
#           }
#           console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#           window._bokeh_is_loading = js_urls.length;
#           for (var i = 0; i < js_urls.length; i++) {
#             var url = js_urls[i];
#             var s = document.createElement('script');
#             s.src = url;
#             s.async = false;
#             s.onreadystatechange = s.onload = function() {
#               window._bokeh_is_loading--;
#               if (window._bokeh_is_loading === 0) {
#                 console.log("Bokeh: all BokehJS libraries loaded");
#                 run_callbacks()
#               }
#             };
#             s.onerror = function() {
#               console.warn("failed to load library " + url);
#             };
#             console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#             document.getElementsByTagName("head")[0].appendChild(s);
#           }
#         };var js_urls = ['https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.js', 'https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.js', 'https://cdn.pydata.org/bokeh/release/bokeh-compiler-0.11.0.min.js'];
#
#         var inline_js = [
#           function(Bokeh) {
#             Bokeh.set_log_level("info");
#           },
#           function(Bokeh) {
#             console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.css");
#             Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.css");
#             console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.css");
#             Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.css");
#           }
#         ];
#
#         function run_inline_js() {
#           for (var i = 0; i < inline_js.length; i++) {
#             inline_js[i](window.Bokeh);
#           }
#         }
#
#         if (window._bokeh_is_loading === 0) {
#           console.log("Bokeh: BokehJS loaded, going straight to plotting");
#           run_inline_js();
#         } else {
#           load_libs(js_urls, function() {
#             console.log("Bokeh: BokehJS plotting callback run at", now());
#             run_inline_js();
#           });
#         }
#       }(this));
#     </script>
#     <div>
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span>BokehJS successfully loaded.</span>
#     </div>
#     <div class="plotdiv" id="ce22158d-36c4-4df4-a083-b9f8f7ec5040"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ce22158d-36c4-4df4-a083-b9f8f7ec5040");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ce22158d-36c4-4df4-a083-b9f8f7ec5040' but no matching script tag was found. ")
#       return false;
#     }var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"f94ce9f4-4772-43fc-ad99-23e1582ab16f": {"title": "Bokeh Application", "version": "0.11.0", "roots": {"root_ids": ["85100ea1-38ed-4ec2-9019-25c9c527940c", "ebfa1c22-1a6c-4dd4-a0db-04b64b5d96d4"], "references": [{"type": "Line", "id": "c71ab31f-2e16-481c-946f-97452fede095", "attributes": {"line_alpha": {"value": 0.1}, "y": {"field": "y"}, "line_color": {"value": "#1f77b4"}, "x": {"field": "x"}}}, {"type": "Circle", "id": "c8c3bfc0-e702-4aa9-b0c1-1b392b2588b2", "attributes": {"y": {"field": "y"}, "line_alpha": {"value": 0.1}, "line_color": {"value": "#1f77b4"}, "fill_alpha": {"value": 0.1}, "x": {"field": "x"}, "size": {"value": 6, "units": "screen"}, "fill_color": {"value": "#1f77b4"}}}, {"type": "Line", "id": "59ae968c-a149-488e-b3a3-f2b991812143", "attributes": {"line_alpha": {"value": 0.1}, "y": {"field": "y"}, "line_color": {"value": "#1f77b4"}, "x": {"field": "x"}, "line_dash": [4, 4]}}, {"type": "BasicTickFormatter", "id": "29c41bd9-b609-4ee2-9d0a-0cf7835087dc", "attributes": {}}, {"type": "LinearAxis", "id": "02a16617-25a1-4a29-9fe1-4453521cdab3", "attributes": {"formatter": {"type": "BasicTickFormatter", "id": "29c41bd9-b609-4ee2-9d0a-0cf7835087dc"}, "ticker": {"type": "BasicTicker", "id": "9090093a-773e-4f65-bb45-cf6955a1fc4d"}, "axis_label": "x", "plot": {"type": "Plot", "id": "85100ea1-38ed-4ec2-9019-25c9c527940c", "subtype": "Figure"}}}, {"type": "LinearAxis", "id": "40857a7b-35cc-4787-abdf-4630d1aaed58", "attributes": {"formatter": {"type": "BasicTickFormatter", "id": "30b64d97-6e53-4652-9fcd-211cf0da82b8"}, "ticker": {"type": "BasicTicker", "id": "19029e59-4f59-45ae-99c0-edee3fd3668e"}, "axis_label": "y", "plot": {"type": "Plot", "id": "85100ea1-38ed-4ec2-9019-25c9c527940c", "subtype": "Figure"}}}, {"type": "BasicTicker", "id": "5a4ed513-26cd-48f2-a3f5-f9dc2ac37c25", "attributes": {}}, {"type": "BasicTickFormatter", "id": "3dd71dcd-eb4f-4665-b753-12a177555024", "attributes": {}}, {"type": "BasicTicker", "id": "19029e59-4f59-45ae-99c0-edee3fd3668e", "attributes": {}}, {"type": "ToolEvents", "id": "b093ae15-6b3f-49b3-8326-1abebcfb2648", "attributes": {}}, {"type": "PanTool", "id": "d01e9ff9-5975-4a80-bd2b-0570a19a1690", "attributes": {"plot": {"type": "Plot", "id": "85100ea1-38ed-4ec2-9019-25c9c527940c", "subtype": "Figure"}}}, {"type": "Grid", "id": "97ff79b8-17c0-4231-a649-a00364b9a675", "attributes": {"dimension": 1, "ticker": {"type": "LogTicker", "id": "266e02a7-c99d-4487-9a25-2a65e6280480"}, "plot": {"type": "Plot", "id": "ebfa1c22-1a6c-4dd4-a0db-04b64b5d96d4", "subtype": "Figure"}}}, {"type": "GlyphRenderer", "id": "31a71898-9191-4452-8cf0-dc920bc0d876", "attributes": {"selection_glyph": null, "glyph": {"type": "Line", "id": "7cbbf087-c59f-4c0e-8317-7e628649e974"}, "nonselection_glyph": {"type": "Line", "id": "d6eb8c5c-49d8-4268-b28e-aec9d49991dc"}, "data_source": {"type": "ColumnDataSource", "id": "0215b14d-8562-4f7b-a0d5-ddaefe4a07a6"}, "hover_glyph": null}}, {"type": "PanTool", "id": "41a8d927-7b74-40fc-9836-7683dc284420", "attributes": {"plot": {"type": "Plot", "id": "ebfa1c22-1a6c-4dd4-a0db-04b64b5d96d4", "subtype": "Figure"}}}, {"type": "Line", "id": "d6eb8c5c-49d8-4268-b28e-aec9d49991dc", "attributes": {"line_alpha": {"value": 0.1}, "y": {"field": "y"}, "line_color": {"value": "#1f77b4"}, "x": {"field": "x"}}}, {"type": "DataRange1d", "id": "be850056-efb7-4fff-af40-4da4ffd5b781", "attributes": {"callback": null}}, {"type": "DataRange1d", "id": "eee4d796-79a5-485e-bff8-f189bc91078a", "attributes": {"callback": null}}, {"type": "GlyphRenderer", "id": "833f712b-16a0-4677-976e-76229672eca0", "attributes": {"selection_glyph": null, "glyph": {"type": "Line", "id": "7c9770b4-486b-49b3-b89a-6663fbc40470"}, "nonselection_glyph": {"type": "Line", "id": "e409dfcd-3519-4bba-a92f-f13114086e22"}, "data_source": {"type": "ColumnDataSource", "id": "1481bf39-c3f1-4304-aa26-0fb1b6907bb7"}, "hover_glyph": null}}, {"type": "GlyphRenderer", "id": "5165239d-161c-40f0-ad6e-7f4fc2625efd", "attribu ...

# %% [markdown]
# ## Vectorized Colors and Sizes

# %%
import numpy as np

from bokeh.plotting import figure, output_file, show

# prepare some data
N = 4000
x = np.random.random(size=N) * 100
y = np.random.random(size=N) * 100
radii = np.random.random(size=N) * 1.5
colors = [
    "#%02x%02x%02x" % (int(r), int(g), 150) for r, g in zip(50+2*x, 30+2*y)
]

# output to static HTML file (with CDN resources)
# output_file("color_scatter.html", title="color_scatter.py example", mode="cdn")
output_notebook()

TOOLS="resize,crosshair,pan,wheel_zoom,box_zoom,reset,box_select,lasso_select"

# create a new plot with the tools above, and explicit ranges
p = figure(tools=TOOLS, x_range=(0,100), y_range=(0,100))

# add a circle renderer with vectorized colors and sizes
p.circle(x,y, radius=radii, fill_color=colors, fill_alpha=0.6, line_color=None)

# show the results
show(p)

# %%
import bokeh.sampledata; bokeh.sampledata.download()
# Out:
# Creating ~/.bokeh directory
# Creating C:\Users\kyoun/.bokeh\data directory
# Using data directory: C:\Users\kyoun/.bokeh\data
# Downloading: CGM.csv (1589982 bytes)
#    1589982 [100.00%]
# Downloading: US_Counties.zip (3182088 bytes)
#    3182088 [100.00%]
# Unpacking: US_Counties.csv
# Downloading: us_cities.json (713565 bytes)
#     713565 [100.00%]
# Downloading: unemployment09.csv (253301 bytes)
#     253301 [100.00%]
# Downloading: AAPL.csv (166698 bytes)
#     166698 [100.00%]
# Downloading: FB.csv (9706 bytes)
#       9706 [100.00%]
# Downloading: GOOG.csv (113894 bytes)
#     113894 [100.00%]
# Downloading: IBM.csv (165625 bytes)
#     165625 [100.00%]
# Downloading: MSFT.csv (161614 bytes)
#     161614 [100.00%]
# Downloading: WPP2012_SA_DB03_POPULATION_QUINQUENNIAL.zip (5148539 bytes)
#    5148539 [100.00%]
# Unpacking: WPP2012_SA_DB03_POPULATION_QUINQUENNIAL.csv
# Downloading: gapminder_fertility.csv (64346 bytes)
#      64346 [100.00%]
# Downloading: gapminder_population.csv (94509 bytes)
#      94509 [100.00%]
# Downloading: gapminder_life_expectancy.csv (73243 bytes)
#      73243 [100.00%]
# Downloading: gapminder_regions.csv (7781 bytes)
#       7781 [100.00%]
# Downloading: world_cities.zip (646858 bytes)
#     646858 [100.00%]
# Unpacking: world_cities.csv
# Downloading: airports.json (6373 bytes)
#       6373 [100.00%]
# Downloading: movies.db.zip (5067833 bytes)
#    4882432 [ 96.34%]
